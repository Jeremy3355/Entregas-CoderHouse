# %% [markdown]
# # Librerias

# %%
import pandas as pd

# %% [markdown]
# # Creacion de DataFrames

# %%
# Analisis de criptomonedas #
df_crypto = pd.read_csv('https://drive.google.com/uc?export=download&id=1s41Nl05M-mzisjTf484yYgIhR4zHCVCU')

# Analisis usuarios del banco portugues#
df_bank_cust = pd.read_csv('https://drive.google.com/uc?export=download&id=1UFw9gS4mSOUdXYkPm872c6IL3R0_Rpnt')

# Analisis de genero de peliculas #
df_movies = pd.read_csv('https://drive.google.com/uc?id=1xwvxjhvriGeHq8i7rOYXbszLcXrTm8Vl', low_memory = False)

# %% [markdown]
# # Analisis rentabilidad de criptomonedas
#
# Los datos en el siguente dataset son datos historicos obtenidos del propio mercado de criptomonedas. A traves del mismo se va a desarrollar una prediccion de precios de cada criptomoneda para determinar su viabilidad y riesgo.
#
# Las columnas a utilizar seran:
# * `symbol`: nombre abreviado de la moneda.
# * `name`: nombre de la moneda.
# * `date`: fecha del dia en el que se obtuvieron los datos.
# * `ranknow`: ranking en el que se encontraba la moneda en esea fecha.
# * `open`: precio de apertura referido a esa fecha.
# * `high`: precio maximo referido a esa fecha.
# * `low`: precio minimo referido a esa fecha.
# * `close`: precio de cierre referido a esa fecha.
# * `volume`: volumne de mercado referido a esa fecha.
#
# La prediccion de precios se haria a traves de las clumnas `symbol`, `name`, `date`, `open`, `high`, `low`, `close`, `volume`.
#
# El analisis de viabilidad y riesgo se podria hacer una vez teniendo la prediccion de precio y haciendo uso de la columna `ranknow`.

# %%
df_crypto
# Out:
#              slug symbol       name        date  ranknow      open      high  \
# 0         bitcoin    BTC    Bitcoin  2013-04-28        1    135.30    135.98
# 1         bitcoin    BTC    Bitcoin  2013-04-29        1    134.44    147.49
# 2         bitcoin    BTC    Bitcoin  2013-04-30        1    144.00    146.93
# 3         bitcoin    BTC    Bitcoin  2013-05-01        1    139.00    139.89
# 4         bitcoin    BTC    Bitcoin  2013-05-02        1    116.38    125.60
# ...           ...    ...        ...         ...      ...       ...       ...
# 942292  project-x  NANOX  Project-X  2018-11-26     1727  22424.60  23049.30
# 942293  project-x  NANOX  Project-X  2018-11-27     1727  20711.90  23742.10
# 942294  project-x  NANOX  Project-X  2018-11-28     1727  23320.90  25235.10
# 942295  project-x  NANOX  Project-X  2018-11-29     1727  24543.53  24582.47
# 942296  project-x  NANOX  Project-X  2018-11-30     1727  22872.09  23086.98
#
# ...

# %% [markdown]
# # Analisis de depositos bancarios
#
# El sigeunte dataset recopila datos sobre una encuesta de merketing de un banco portugues de personas encuestadas con el fin de determinar si realizaran depositos en su banco o no. En un principio la idea principal de analisis sera predecir en base a los datos obtenido, si el encestado realizara un deposito.
#
# Las columnas a utilizar seran:
#
# Datos relacionados con el encuestado:
# * `age`: edad.
# * `job`: ocupacion.
# * `marital`: estado civil.
# * `education`: educacion.
# * `default`: tiene una deuda por credito?
# * `housing`: realizo un prestamo por vivienda?
# * `loan`: realizo un prestamo?
#
# Datos relacionados con la encuesta:
# * `contact`: medio por el que fue contactado.
# * `day`: dai de contacto.
# * `month`: mes de contacto.
# * `duration`: duracion del contacto en segundos.
# * `month`: mes en el que fue contactado.
#
# Todas la columnas anteriormente detalladas seran utilizadas para predecir al columna `term_deposit`

# %%
df_bank_cust
# Out:
#        age           job  marital  education default  balance housing loan  \
# 0       58    management  married   tertiary      no     2143     yes   no
# 1       44    technician   single  secondary      no       29     yes   no
# 2       33  entrepreneur  married  secondary      no        2     yes  yes
# 3       47   blue-collar  married    unknown      no     1506     yes   no
# 4       33       unknown   single    unknown      no        1      no   no
# ...    ...           ...      ...        ...     ...      ...     ...  ...
# 42634   21       student   single  secondary      no     2488      no   no
# 42635   87       retired  married    primary      no     2190      no   no
# 42636   34   blue-collar  married    primary      no     6718      no   no
# 42637   22       student   single  secondary      no      254      no   no
# 42638   32    management   single   tertiary      no     1962      no   no
#
# ...

# %% [markdown]
# # Analisis genero de peliculas
#
# El sigeunte dataset recopila datos sobre pelicula. En un principio la idea principal de analisis sera predecir el genero de la pelicula en funcion de sus actores, director y escritor.
#
# Las columnas a utilizar seran:
# * `original_title`: titulo original de la pelicula.
# * `duration`: duracion de la pelicula.
# * `director`: director de la pelicula.
# * `writer`: escritor del guion.
# * `production_company`: empresa que produjo la pelicula.
# * `actors`: actores.
# * `description`: sinopsis de la pelicula.
#
# Todas la columnas anteriormente detalladas seran utilizadas para predecir al columna `genre`

# %%
df_movies
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...
